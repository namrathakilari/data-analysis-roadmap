# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv(r"C:\Users\Namratha Kilari\Downloads\data-analysis-roadmap\practice_projects\student_scores\Expanded_data_with_more_features.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30641 entries, 0 to 30640
# Data columns (total 15 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Unnamed: 0           30641 non-null  int64
#  1   Gender               30641 non-null  object
#  2   EthnicGroup          28801 non-null  object
#  3   ParentEduc           28796 non-null  object
#  4   LunchType            30641 non-null  object
#  5   TestPrep             28811 non-null  object
#  6   ParentMaritalStatus  29451 non-null  object
#  7   PracticeSport        30010 non-null  object
#  8   IsFirstChild         29737 non-null  object
#  9   NrSiblings           29069 non-null  float64
#  10  TransportMeans       27507 non-null  object
#  11  WklyStudyHours       29686 non-null  object
#  12  MathScore            30641 non-null  int64
#  13  ReadingScore         30641 non-null  int64
#  14  WritingScore         30641 non-null  int64
# ...

# %%
df=df.drop_duplicates()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30641 entries, 0 to 30640
# Data columns (total 15 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Unnamed: 0           30641 non-null  int64
#  1   Gender               30641 non-null  object
#  2   EthnicGroup          28801 non-null  object
#  3   ParentEduc           28796 non-null  object
#  4   LunchType            30641 non-null  object
#  5   TestPrep             28811 non-null  object
#  6   ParentMaritalStatus  29451 non-null  object
#  7   PracticeSport        30010 non-null  object
#  8   IsFirstChild         29737 non-null  object
#  9   NrSiblings           29069 non-null  float64
#  10  TransportMeans       27507 non-null  object
#  11  WklyStudyHours       29686 non-null  object
#  12  MathScore            30641 non-null  int64
#  13  ReadingScore         30641 non-null  int64
#  14  WritingScore         30641 non-null  int64
# ...

# %%
df.head()
# Out:
#    Unnamed: 0  Gender EthnicGroup          ParentEduc     LunchType TestPrep  \
# 0           0  female         NaN   bachelor's degree      standard     none
# 1           1  female     group C        some college      standard      NaN
# 2           2  female     group B     master's degree      standard     none
# 3           3    male     group A  associate's degree  free/reduced     none
# 4           4    male     group C        some college      standard     none
#
#   ParentMaritalStatus PracticeSport IsFirstChild  NrSiblings TransportMeans  \
# 0             married     regularly          yes         3.0     school_bus
# 1             married     sometimes          yes         0.0            NaN
# 2              single     sometimes          yes         4.0     school_bus
# 3             married         never           no         1.0            NaN
# 4             married     sometimes          yes         0.0     school_bus
#
# ...

# %%
df=df.drop(columns=['TestPrep','PracticeSport'])
df
# Out:
#        Unnamed: 0  Gender EthnicGroup          ParentEduc     LunchType  \
# 0               0  female         NaN   bachelor's degree      standard
# 1               1  female     group C        some college      standard
# 2               2  female     group B     master's degree      standard
# 3               3    male     group A  associate's degree  free/reduced
# 4               4    male     group C        some college      standard
# ...           ...     ...         ...                 ...           ...
# 30636         816  female     group D         high school      standard
# 30637         890    male     group E         high school      standard
# 30638         911  female         NaN         high school  free/reduced
# 30639         934  female     group D  associate's degree      standard
# 30640         960    male     group B        some college      standard
#
#       ParentMaritalStatus IsFirstChild  NrSiblings TransportMeans  \
# ...

# %%
df=df.drop(columns=df.columns[0])
df
# Out:
#        Gender EthnicGroup          ParentEduc     LunchType  \
# 0      female         NaN   bachelor's degree      standard
# 1      female     group C        some college      standard
# 2      female     group B     master's degree      standard
# 3        male     group A  associate's degree  free/reduced
# 4        male     group C        some college      standard
# ...       ...         ...                 ...           ...
# 30636  female     group D         high school      standard
# 30637    male     group E         high school      standard
# 30638  female         NaN         high school  free/reduced
# 30639  female     group D  associate's degree      standard
# 30640    male     group B        some college      standard
#
#       ParentMaritalStatus IsFirstChild  NrSiblings TransportMeans  \
# 0                 married          yes         3.0     school_bus
# 1                 married          yes         0.0            NaN
# ...

# %%
df=df.drop(columns=df.columns[3:5])
df
# Out:
#        Gender EthnicGroup          ParentEduc IsFirstChild  NrSiblings  \
# 0      female         NaN   bachelor's degree          yes         3.0
# 1      female     group C        some college          yes         0.0
# 2      female     group B     master's degree          yes         4.0
# 3        male     group A  associate's degree           no         1.0
# 4        male     group C        some college          yes         0.0
# ...       ...         ...                 ...          ...         ...
# 30636  female     group D         high school           no         2.0
# 30637    male     group E         high school           no         1.0
# 30638  female         NaN         high school           no         1.0
# 30639  female     group D  associate's degree           no         3.0
# 30640    male     group B        some college           no         1.0
#
#       TransportMeans WklyStudyHours  MathScore  ReadingScore  WritingScore
# ...

# %%
df=df.dropna()
df
# Out:
#        Gender EthnicGroup          ParentEduc IsFirstChild  NrSiblings  \
# 2      female     group B     master's degree          yes         4.0
# 4        male     group C        some college          yes         0.0
# 5      female     group B  associate's degree          yes         1.0
# 6      female     group B        some college           no         1.0
# 7        male     group B        some college          yes         1.0
# ...       ...         ...                 ...          ...         ...
# 30635    male     group C        some college           no         2.0
# 30636  female     group D         high school           no         2.0
# 30637    male     group E         high school           no         1.0
# 30639  female     group D  associate's degree           no         3.0
# 30640    male     group B        some college           no         1.0
#
#       TransportMeans WklyStudyHours  MathScore  ReadingScore  WritingScore
# ...

# %%
df["Gender"]=df["Gender"].apply(lambda x: 1 if x=="female" else 0)
df
# Out:
# C:\Users\Namratha Kilari\AppData\Local\Temp\ipykernel_4516\4076384307.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Gender"]=df["Gender"].apply(lambda x: 1 if x=="female" else 0)
#        Gender EthnicGroup          ParentEduc IsFirstChild  NrSiblings  \
# 2           1     group B     master's degree          yes         4.0
# 4           0     group C        some college          yes         0.0
# 5           1     group B  associate's degree          yes         1.0
# 6           1     group B        some college           no         1.0
# 7           0     group B        some college          yes         1.0
# ...       ...         ...                 ...          ...         ...
# ...

# %%
df["EthnicGroup"].nunique()
# Out:
# 5

# %%
df["EthnicGroup"]=df["EthnicGroup"].str.replace("group A","A")
df["EthnicGroup"]=df["EthnicGroup"].str.replace("group B","B")
df["EthnicGroup"]=df["EthnicGroup"].str.replace("group C","C")
df["EthnicGroup"]=df["EthnicGroup"].str.replace("group D","D")
df["EthnicGroup"]=df["EthnicGroup"].str.replace("group E","E")
df
# Out:
# C:\Users\Namratha Kilari\AppData\Local\Temp\ipykernel_4516\557498362.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["EthnicGroup"]=df["EthnicGroup"].str.replace("group A","A")
# C:\Users\Namratha Kilari\AppData\Local\Temp\ipykernel_4516\557498362.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["EthnicGroup"]=df["EthnicGroup"].str.replace("group B","B")
# C:\Users\Namratha Kilari\AppData\Local\Temp\ipykernel_4516\557498362.py:3: SettingWithCopyWarning:
# ...

# %%
df["NrSiblings"]=df["NrSiblings"].astype(int)
df
# Out:
# C:\Users\Namratha Kilari\AppData\Local\Temp\ipykernel_4516\2424177993.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["NrSiblings"]=df["NrSiblings"].astype(int)
#        Gender EthnicGroup          ParentEduc IsFirstChild  NrSiblings  \
# 2           1           B     master's degree          yes           4
# 4           0           C        some college          yes           0
# 5           1           B  associate's degree          yes           1
# 6           1           B        some college           no           1
# 7           0           B        some college          yes           1
# ...       ...         ...                 ...          ...         ...
# ...

# %%
df=df.reset_index(drop=True)
df
# Out:
#        Gender EthnicGroup          ParentEduc IsFirstChild  NrSiblings  \
# 0           1           B     master's degree          yes           4
# 1           0           C        some college          yes           0
# 2           1           B  associate's degree          yes           1
# 3           1           B        some college           no           1
# 4           0           B        some college          yes           1
# ...       ...         ...                 ...          ...         ...
# 21689       0           C        some college           no           2
# 21690       1           D         high school           no           2
# 21691       0           E         high school           no           1
# 21692       1           D  associate's degree           no           3
# 21693       0           B        some college           no           1
#
#       TransportMeans WklyStudyHours  MathScore  ReadingScore  WritingScore
# ...

# %%
df["IsFirstChild"]=df["IsFirstChild"].apply(lambda x: 1 if x=="yes" else 0)
df
# Out:
#        Gender EthnicGroup          ParentEduc  IsFirstChild  NrSiblings  \
# 0           1           B     master's degree             1           4
# 1           0           C        some college             1           0
# 2           1           B  associate's degree             1           1
# 3           1           B        some college             0           1
# 4           0           B        some college             1           1
# ...       ...         ...                 ...           ...         ...
# 21689       0           C        some college             0           2
# 21690       1           D         high school             0           2
# 21691       0           E         high school             0           1
# 21692       1           D  associate's degree             0           3
# 21693       0           B        some college             0           1
#
#       TransportMeans WklyStudyHours  MathScore  ReadingScore  WritingScore
# ...

# %%
df=df.drop(columns=df.columns[2])
df
# Out:
#        Gender EthnicGroup  IsFirstChild  NrSiblings TransportMeans  \
# 0           1           B             1           4     school_bus
# 1           0           C             1           0     school_bus
# 2           1           B             1           1     school_bus
# 3           1           B             0           1        private
# 4           0           B             1           1        private
# ...       ...         ...           ...         ...            ...
# 21689       0           C             0           2     school_bus
# 21690       1           D             0           2     school_bus
# 21691       0           E             0           1        private
# 21692       1           D             0           3     school_bus
# 21693       0           B             0           1     school_bus
#
#       WklyStudyHours  MathScore  ReadingScore  WritingScore
# 0                < 5         87            93            91
# ...

# %%
df=df.rename(columns={"TransportMeans":"SchoolBus"})
df
# Out:
#        Gender EthnicGroup  IsFirstChild  NrSiblings   SchoolBus  \
# 0           1           B             1           4  school_bus
# 1           0           C             1           0  school_bus
# 2           1           B             1           1  school_bus
# 3           1           B             0           1     private
# 4           0           B             1           1     private
# ...       ...         ...           ...         ...         ...
# 21689       0           C             0           2  school_bus
# 21690       1           D             0           2  school_bus
# 21691       0           E             0           1     private
# 21692       1           D             0           3  school_bus
# 21693       0           B             0           1  school_bus
#
#       WklyStudyHours  MathScore  ReadingScore  WritingScore
# 0                < 5         87            93            91
# 1             5 - 10         76            78            75
# ...

# %%
df["SchoolBus"]=df["SchoolBus"].apply(lambda x: 1 if x=="school_bus" else 0)
df
# Out:
#        Gender EthnicGroup  IsFirstChild  NrSiblings  SchoolBus WklyStudyHours  \
# 0           1           B             1           4          1            < 5
# 1           0           C             1           0          1         5 - 10
# 2           1           B             1           1          1         5 - 10
# 3           1           B             0           1          0         5 - 10
# 4           0           B             1           1          0           > 10
# ...       ...         ...           ...         ...        ...            ...
# 21689       0           C             0           2          1         5 - 10
# 21690       1           D             0           2          1         5 - 10
# 21691       0           E             0           1          0         5 - 10
# 21692       1           D             0           3          1         5 - 10
# 21693       0           B             0           1          1         5 - 10
#
# ...
